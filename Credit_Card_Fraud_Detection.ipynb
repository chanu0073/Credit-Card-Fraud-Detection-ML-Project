# %% [markdown]
# <a href="https://colab.research.google.com/github/chanu0073/Credit-Card-Fraud-Detection-ML-Project/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/credit_data.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data['Class'].groupby(data['Class']).count()
# Out:
# Class
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
X.values.std()
# Out:
# np.float64(19100.296805330552)

# %%
plt.figure(figsize=(15, 6))

# Plotting boxplots
sns.boxplot(data=X[['Time', 'Amount']])
plt.xticks(rotation=45)
plt.title("Boxplot of Features to Detect Outliers")
plt.show()

# %%
print(X.dtypes)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X[['Time','Amount']] = scaler.fit_transform(X[['Time','Amount']])

# %%
X.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.239599  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount
# ...

# %%
X.values.std()
# Out:
# np.float64(1.0445372201925325)

# %%
print("Mean after scaling:", np.mean(X[['Time', 'Amount']].values))
print("Std after scaling:", np.std(X[['Time', 'Amount']].values))
# Out:
# Mean after scaling: -1.4050836839687523e-16
# Std after scaling: 1.0

# %%
plt.figure(figsize=(15, 6))

# Plotting boxplots
sns.boxplot(data=X[['Time', 'Amount']])
plt.xticks(rotation=45)
plt.title("Boxplot of Features to Detect Outliers")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
training_data_prediction = model.predict(X_train)

# %%
from sklearn.metrics import accuracy_score

# %%
training_data_accuracy = accuracy_score(training_data_prediction, y_train)
print(training_data_accuracy)
# Out:
# 0.9992407118874673

# %%
test_data_prediction = model.predict(X_test)

# %%
test_data_accuracy = accuracy_score(test_data_prediction, y_test)
print(test_data_accuracy)
# Out:
# 0.9991046662687406

# %%
test_input = X_test.iloc[[4]]
prediction = model.predict(test_input)
print(prediction)

if prediction[0] == 0:
  print('The transaction is legit')
else:
  print('The transaction is fraudulent')
# Out:
# [0]
# The transaction is legit

# %%
print(y_test.iloc[4])
# Out:
# 0
